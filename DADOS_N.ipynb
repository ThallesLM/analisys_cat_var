# %% [markdown]
# <a href="https://colab.research.google.com/github/ThallesLM/analisys_cat_var/blob/main/DADOS_N.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
dados=pd.read_excel("/content/drive/MyDrive/Base de dados/Dados.xlsx")

# %%
dados
# Out:
#      Unnamed: 0                   Escolaridade     Raça    Idade  \
# 0           1.0          Ensino Médio Completo    Negra     29.0
# 1           2.0  Ensino Fundamental Incompleto    Parda     26.0
# 2           3.0        Ensino Médio Incompleto    Parda     37.0
# 3           4.0       Ensino Superior Completo   Branca     41.0
# 4           5.0          Ensino Médio Completo    Parda     27.0
# ..          ...                            ...      ...      ...
# 350         NaN                            NaN    Range     27.0
# 351         NaN                            NaN  Minimum     18.0
# 352         NaN                            NaN  Maximum     45.0
# 353         NaN                            NaN      Sum  10014.0
# 354         NaN                            NaN    Count    338.0
#
#                        Classificação de idade      Contexto_familiar  \
# 0            Adultez Emergente( 20 a 40 anos)   Família monoparental
# ...

# %%
nulos=dados.isnull().sum()

# %%
print(nulos)
# Out:
# Unnamed: 0                                 16
# Escolaridade                               16
# Raça                                        2
# Idade                                       4
# Classificação de idade                      4
# Contexto_familiar                           3
# Número_filhos_menores                      16
# Número_pessoas_residência                  16
# Atividade_remunerada                       16
# Renda_familiar                             16
# Inserção_programa_governo_federal          16
# Valor_do_benefício                         16
# Rede_apoio_gestantes                       16
# Tipo_de_rede_de_apoio                      16
# Gestação_planejada                         16
# Pré_natal                                  16
# Fumante                                    16
# Gestantes_fumantes                         16
# Consumo_de_álcool                          16
# Uso_substâncias_ilícitas                   16
# ...

# %%
dados.dtypes
# Out:
# Unnamed: 0                                 float64
# Escolaridade                                object
# Raça                                        object
# Idade                                      float64
# Classificação de idade                      object
# Contexto_familiar                           object
# Número_filhos_menores                       object
# Número_pessoas_residência                   object
# Atividade_remunerada                        object
# Renda_familiar                              object
# Inserção_programa_governo_federal           object
# Valor_do_benefício                          object
# Rede_apoio_gestantes                        object
# Tipo_de_rede_de_apoio                       object
# Gestação_planejada                          object
# Pré_natal                                   object
# Fumante                                     object
# Gestantes_fumantes                          object
# ...

# %%
vu=dados['Idade'].unique().sum

# %%
resultado = conta_unicos(dados, 'Idade')

# O dicionário 'resultado' conterá as seguintes informações:
print(f"Número de valores únicos em 'Idade': {resultado['n_unicos']}")
print(f"Frequências dos valores únicos em 'Idade':")
print(resultado['frequencias'])
# Out:
# Número de valores únicos em 'Idade': 36
# Frequências dos valores únicos em 'Idade':
#            Valor  Frequência
# 0      28.000000          25
# 1      35.000000          24
# 2      36.000000          18
# 3      24.000000          17
# 4      37.000000          17
# 5      23.000000          17
# 6      31.000000          16
# 7      29.000000          16
# 8      32.000000          15
# 9      25.000000          15
# 10     26.000000          15
# 11     27.000000          14
# 12     33.000000          14
# 13     21.000000          14
# 14     34.000000          13
# 15     19.000000          12
# 16     18.000000          11
# 17     20.000000          10
# 18     30.000000          10
# 19     22.000000          10
# 20     38.000000          10
# 21     39.000000           8
# 22     41.000000           6
# 23     43.000000           4
# 24     40.000000           4
# 25     42.000000           3
# 26     44.000000           3
# 27     45.000000           2
# ...

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
